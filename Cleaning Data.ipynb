# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 =pd.read_csv(r"C:\Users\ghazi\Desktop\delivey details\order_details_table.csv")
df2= pd.read_csv(r"C:\Users\ghazi\Desktop\delivey details\location_details_table.csv")
df3= pd.read_csv(r"C:\Users\ghazi\Desktop\delivey details\delivery_person_table.csv")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    45593 non-null  object
#  1   Order_Date            45593 non-null  object
#  2   Time_Orderd           45593 non-null  object
#  3   Time_Order_picked     45593 non-null  object
#  4   Weatherconditions     45593 non-null  object
#  5   Road_traffic_density  45593 non-null  object
#  6   Vehicle_condition     45593 non-null  int64
#  7   Type_of_order         45593 non-null  object
#  8   Type_of_vehicle       45593 non-null  object
#  9   multiple_deliveries   45593 non-null  object
#  10  Festival              45593 non-null  object
#  11  City                  45593 non-null  object
#  12  Time_taken(min)       45593 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 4.5+ MB

# %%
df1.isnull().sum()
# Out:
# ID                      0
# Order_Date              0
# Time_Orderd             0
# Time_Order_picked       0
# Weatherconditions       0
# Road_traffic_density    0
# Vehicle_condition       0
# Type_of_order           0
# Type_of_vehicle         0
# multiple_deliveries     0
# Festival                0
# City                    0
# Time_taken(min)         0
# dtype: int64

# %%
df1['Order_Date'] = pd.to_datetime(df1['Order_Date'],dayfirst=True,errors='coerce')
df1['Time_Order_picked']= pd.to_datetime(df1['Time_Order_picked'],format='%H:%M:%S',errors='coerce')
df1['Time_Orderd'] = pd.to_datetime(df1['Time_Orderd'],errors='coerce')
# Out:
# C:\Users\ghazi\AppData\Local\Temp\ipykernel_10336\3937880672.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['Time_Orderd'] = pd.to_datetime(df1['Time_Orderd'],errors='coerce')

# %%
df1.columns = df1.columns.str.lower()
df1
# Out:
#             id order_date         time_orderd   time_order_picked  \
# 0      0x4607  2022-03-19 2026-03-18 11:30:00 1900-01-01 11:45:00
# 1      0xb379  2022-03-25 2026-03-18 19:45:00 1900-01-01 19:50:00
# 2      0x5d6d  2022-03-19 2026-03-18 08:30:00 1900-01-01 08:45:00
# 3      0x7a6a  2022-04-05 2026-03-18 18:00:00 1900-01-01 18:10:00
# 4      0x70a2  2022-03-26 2026-03-18 13:30:00 1900-01-01 13:45:00
# ...        ...        ...                 ...                 ...
# 45588  0x7c09  2022-03-24 2026-03-18 11:35:00 1900-01-01 11:45:00
# 45589  0xd641  2022-02-16 2026-03-18 19:55:00 1900-01-01 20:10:00
# 45590  0x4f8d  2022-03-11 2026-03-18 23:50:00 1900-01-01 00:05:00
# 45591  0x5eee  2022-03-07 2026-03-18 13:35:00 1900-01-01 13:40:00
# 45592  0x5fb2  2022-03-02 2026-03-18 17:10:00 1900-01-01 17:15:00
#
#            weatherconditions road_traffic_density  vehicle_condition  \
# 0           conditions Sunny                High                   2
# ...

# %%
df1['multiple_deliveries']=pd.to_numeric(df1['multiple_deliveries'],errors='coerce')

# %%
df1['id'] = df1['id'].astype(str).str.strip()
df1['od'] = df1['id'].replace('',pd.NA)
df1=df1.dropna(subset=['id'])

# %%
df1['id'].unique()[:10]
# Out:
# array(['0x4607', '0xb379', '0x5d6d', '0x7a6a', '0x70a2', '0x9bb4',
#        '0x95b4', '0x9eb2', '0x1102', '0xcdcd'], dtype=object)

# %%
df1.isnull().sum()
# Out:
# id                         0
# order_date                 0
# time_orderd             1731
# time_order_picked          0
# weatherconditions          0
# road_traffic_density       0
# vehicle_condition          0
# type_of_order              0
# type_of_vehicle            0
# multiple_deliveries      993
# festival                   0
# city                       0
# time_taken(min)            0
# od                         0
# dtype: int64

# %%
df1['multiple_deliveries']=df1['multiple_deliveries'].fillna(0)
df1['time_orderd'] = df1['time_orderd'].fillna(df1['time_orderd'].mode()[0])

# %%
df2.columns = df2.columns.str.lower()
df3.columns = df3.columns.str.lower()

# %%
df3.isnull().sum()
# Out:
# id                         0
# delivery_person_id         0
# delivery_person_age        0
# delivery_person_ratings    0
# dtype: int64

# %%
df1.to_csv(r'C:\Users\ghazi\Desktop\delivey details\orders.csv',index=False)
df2.to_csv(r'C:\Users\ghazi\Desktop\delivey details\location.csv',index=False)
df3.to_csv(r'C:\Users\ghazi\Desktop\delivey details\person.csv',index=False)
